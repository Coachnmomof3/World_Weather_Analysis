# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import from Parent folder
import sys 
sys.path.append('../')

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# coordinates

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
#url  OpenWeatherMap 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Begining of Data Retrivel")
print("-------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining of Data Retrivel
# -------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | hervey bay
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 1 | bubaque
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | barkhera
# Processing Record 8 of Set 1 | araguatins
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | inuvik
# Processing Record 11 of Set 1 | olafsvik
# Processing Record 12 of Set 1 | sakaiminato
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | husavik
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | katsina
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | souillac
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | yaguajay
# Processing Record 27 of Set 1 | maine-soroa
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | ballina
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | laguna
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | chodavaram
# Processing Record 37 of Set 1 | xunchang
# Processing Record 38 of Set 1 | pisco
# Processing Record 39 of Set 1 | leningradskiy
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | oistins
# Processing Record 42 of Set 1 | paita
# Processing Record 43 of Set 1 | akureyri
# Processing Record 44 of Set 1 | margate
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | denau
# City not found. Skipping...
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | cairns
# Processing Record 50 of Set 1 | mvomero
# Processing Record 1 of Set 2 | veraval
# Processing Record 2 of Set 2 | namatanai
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | nemuro
# Processing Record 5 of Set 2 | anadyr
# Processing Record 6 of Set 2 | vila
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | saint anthony
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | taunggyi
# Processing Record 15 of Set 2 | zharkent
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | comodoro rivadavia
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | graaff-reinet
# Processing Record 23 of Set 2 | dongsheng
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 2 | qurunbaliyah
# City not found. Skipping...
# Processing Record 27 of Set 2 | mahaicony
# City not found. Skipping...
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | harper
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 2 | mayo
# Processing Record 34 of Set 2 | kodiak
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | changji
# Processing Record 37 of Set 2 | broome
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | kulhudhuffushi
# Processing Record 41 of Set 2 | abha
# Processing Record 42 of Set 2 | baswa
# Processing Record 43 of Set 2 | yuci
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | akdepe
# Processing Record 46 of Set 2 | bandar-e anzali
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | viedma
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | durham
# Processing Record 2 of Set 3 | kahului
# Processing Record 3 of Set 3 | aswan
# Processing Record 4 of Set 3 | walla walla
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | rauma
# Processing Record 7 of Set 3 | flinders
# Processing Record 8 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 3 | duz
# City not found. Skipping...
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | aksu
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | arlit
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | debre tabor
# Processing Record 16 of Set 3 | valdivia
# Processing Record 17 of Set 3 | tasiilaq
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | coihaique
# Processing Record 20 of Set 3 | snasa
# Processing Record 21 of Set 3 | presidente epitacio
# Processing Record 22 of Set 3 | baherden
# Processing Record 23 of Set 3 | moerai
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | segovia
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | punta alta
# Processing Record 28 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | mackay
# Processing Record 31 of Set 3 | kibondo
# Processing Record 32 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 3 | fairbanks
# Processing Record 34 of Set 3 | road town
# Processing Record 35 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | ambovombe
# Processing Record 38 of Set 3 | ciudad bolivar
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | sur
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | lloydminster
# Processing Record 43 of Set 3 | vrede
# Processing Record 44 of Set 3 | cap malheureux
# Processing Record 45 of Set 3 | carnarvon
# Processing Record 46 of Set 3 | cayenne
# Processing Record 47 of Set 3 | hobyo
# Processing Record 48 of Set 3 | buala
# Processing Record 49 of Set 3 | kathu
# Processing Record 50 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | boa vista
# Processing Record 2 of Set 4 | bozova
# Processing Record 3 of Set 4 | beaverlodge
# Processing Record 4 of Set 4 | geraldton
# Processing Record 5 of Set 4 | filingue
# Processing Record 6 of Set 4 | chaumont
# Processing Record 7 of Set 4 | karpathos
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | kloulklubed
# Processing Record 10 of Set 4 | hamilton
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | vao
# Processing Record 14 of Set 4 | luwingu
# Processing Record 15 of Set 4 | ozinki
# Processing Record 16 of Set 4 | matola
# Processing Record 17 of Set 4 | muros
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | freeport
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | bom jardim
# Processing Record 23 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 4 | kokoda
# Processing Record 25 of Set 4 | lavrentiya
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | east london
# Processing Record 28 of Set 4 | puerto suarez
# Processing Record 29 of Set 4 | japura
# Processing Record 30 of Set 4 | yaan
# Processing Record 31 of Set 4 | killybegs
# Processing Record 32 of Set 4 | kununurra
# Processing Record 33 of Set 4 | myaundzha
# Processing Record 34 of Set 4 | kamenka
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | ostrovnoy
# Processing Record 39 of Set 4 | olinda
# Processing Record 40 of Set 4 | sampit
# Processing Record 41 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 42 of Set 4 | lasa
# Processing Record 43 of Set 4 | ostersund
# Processing Record 44 of Set 4 | rio grande
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | isangel
# Processing Record 47 of Set 4 | nizwa
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | carbonear
# Processing Record 50 of Set 4 | koubia
# Processing Record 1 of Set 5 | balabac
# Processing Record 2 of Set 5 | pringsewu
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | krasnogvardeyets
# Processing Record 5 of Set 5 | mme
# City not found. Skipping...
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | oktyabrskiy
# Processing Record 8 of Set 5 | saltillo
# Processing Record 9 of Set 5 | goderich
# Processing Record 10 of Set 5 | belyy yar
# Processing Record 11 of Set 5 | north battleford
# Processing Record 12 of Set 5 | pevek
# Processing Record 13 of Set 5 | nuevitas
# Processing Record 14 of Set 5 | okha
# Processing Record 15 of Set 5 | qaanaaq
# Processing Record 16 of Set 5 | lanigan
# Processing Record 17 of Set 5 | wajima
# Processing Record 18 of Set 5 | asau
# Processing Record 19 of Set 5 | nicoya
# Processing Record 20 of Set 5 | verkhoyansk
# Processing Record 21 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 5 | chokurdakh
# Processing Record 23 of Set 5 | constitucion
# Processing Record 24 of Set 5 | dubbo
# Processing Record 25 of Set 5 | yining
# Processing Record 26 of Set 5 | prince rupert
# Processing Record 27 of Set 5 | santa maria
# Processing Record 28 of Set 5 | canutama
# Processing Record 29 of Set 5 | galle
# Processing Record 30 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 5 | ahipara
# Processing Record 32 of Set 5 | victor harbor
# Processing Record 33 of Set 5 | batagay-alyta
# Processing Record 34 of Set 5 | talnakh
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | hitchin
# Processing Record 37 of Set 5 | kaniama
# Processing Record 38 of Set 5 | axim
# Processing Record 39 of Set 5 | zhigansk
# Processing Record 40 of Set 5 | ouargaye
# Processing Record 41 of Set 5 | dawlatabad
# Processing Record 42 of Set 5 | provideniya
# Processing Record 43 of Set 5 | te anau
# Processing Record 44 of Set 5 | pagudpud
# Processing Record 45 of Set 5 | hambantota
# Processing Record 46 of Set 5 | ishigaki
# Processing Record 47 of Set 5 | chicama
# Processing Record 48 of Set 5 | turayf
# Processing Record 49 of Set 5 | dryden
# Processing Record 50 of Set 5 | elizabeth city
# Processing Record 1 of Set 6 | borba
# Processing Record 2 of Set 6 | half moon bay
# Processing Record 3 of Set 6 | ust-kuyga
# Processing Record 4 of Set 6 | sistranda
# Processing Record 5 of Set 6 | rundu
# Processing Record 6 of Set 6 | kendari
# Processing Record 7 of Set 6 | ngunguru
# Processing Record 8 of Set 6 | egvekinot
# Processing Record 9 of Set 6 | vostok
# Processing Record 10 of Set 6 | haines junction
# Processing Record 11 of Set 6 | nuuk
# Processing Record 12 of Set 6 | saint-augustin
# Processing Record 13 of Set 6 | honavar
# Processing Record 14 of Set 6 | port hawkesbury
# Processing Record 15 of Set 6 | oranjestad
# Processing Record 16 of Set 6 | bereda
# Processing Record 17 of Set 6 | mareeba
# Processing Record 18 of Set 6 | antsohihy
# Processing Record 19 of Set 6 | san vicente
# Processing Record 20 of Set 6 | avila
# Processing Record 21 of Set 6 | solhan
# Processing Record 22 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 6 | krasnoselkup
# Processing Record 26 of Set 6 | mongo
# Processing Record 27 of Set 6 | oktyabrskoye
# Processing Record 28 of Set 6 | kapit
# Processing Record 29 of Set 6 | saalfelden
# City not found. Skipping...
# Processing Record 30 of Set 6 | sao filipe
# Processing Record 31 of Set 6 | guerrero negro
# Processing Record 32 of Set 6 | srivaikuntam
# Processing Record 33 of Set 6 | henties bay
# Processing Record 34 of Set 6 | clovis
# Processing Record 35 of Set 6 | trincomalee
# Processing Record 36 of Set 6 | diamantina
# Processing Record 37 of Set 6 | wanning
# Processing Record 38 of Set 6 | byron bay
# Processing Record 39 of Set 6 | marsa matruh
# Processing Record 40 of Set 6 | la belgica
# Processing Record 41 of Set 6 | antalaha
# Processing Record 42 of Set 6 | yambio
# Processing Record 43 of Set 6 | sorong
# Processing Record 44 of Set 6 | deputatskiy
# Processing Record 45 of Set 6 | ylojarvi
# Processing Record 46 of Set 6 | kultuk
# Processing Record 47 of Set 6 | college
# Processing Record 48 of Set 6 | salinas
# Processing Record 49 of Set 6 | labuhan
# Processing Record 50 of Set 6 | panna
# Processing Record 1 of Set 7 | arinos
# Processing Record 2 of Set 7 | kuching
# Processing Record 3 of Set 7 | mumford
# Processing Record 4 of Set 7 | dhuwaran
# Processing Record 5 of Set 7 | diffa
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | pauini
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | jiayuguan
# Processing Record 10 of Set 7 | new ulm
# Processing Record 11 of Set 7 | victoria
# Processing Record 12 of Set 7 | kaitangata
# Processing Record 13 of Set 7 | nioro
# Processing Record 14 of Set 7 | richards bay
# Processing Record 15 of Set 7 | kieta
# Processing Record 16 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 7 | arrifes
# Processing Record 18 of Set 7 | kishni
# Processing Record 19 of Set 7 | dillon
# Processing Record 20 of Set 7 | varkaus
# Processing Record 21 of Set 7 | bethel
# Processing Record 22 of Set 7 | alice springs
# Processing Record 23 of Set 7 | lagoa
# Processing Record 24 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 7 | grand-santi
# Processing Record 26 of Set 7 | navahrudak
# Processing Record 27 of Set 7 | reconquista
# Processing Record 28 of Set 7 | kutum
# Processing Record 29 of Set 7 | bathsheba
# Processing Record 30 of Set 7 | flin flon
# Processing Record 31 of Set 7 | port-gentil
# Processing Record 32 of Set 7 | giyon
# Processing Record 33 of Set 7 | kautokeino
# Processing Record 34 of Set 7 | san javier
# Processing Record 35 of Set 7 | perbaungan
# Processing Record 36 of Set 7 | okhotsk
# Processing Record 37 of Set 7 | nicolas bravo
# Processing Record 38 of Set 7 | rosignano marittimo
# Processing Record 39 of Set 7 | gatton
# Processing Record 40 of Set 7 | mtwara
# Processing Record 41 of Set 7 | cidreira
# Processing Record 42 of Set 7 | tessalit
# Processing Record 43 of Set 7 | upernavik
# Processing Record 44 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | praia da vitoria
# Processing Record 46 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 7 | safaga
# Processing Record 48 of Set 7 | trairi
# Processing Record 49 of Set 7 | brownsville
# Processing Record 50 of Set 7 | tiruchchendur
# Processing Record 1 of Set 8 | hokitika
# Processing Record 2 of Set 8 | malko tarnovo
# Processing Record 3 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 4 of Set 8 | san ramon
# Processing Record 5 of Set 8 | tignere
# Processing Record 6 of Set 8 | dawei
# Processing Record 7 of Set 8 | sangar
# Processing Record 8 of Set 8 | fuzhou
# Processing Record 9 of Set 8 | nchelenge
# Processing Record 10 of Set 8 | sabang
# Processing Record 11 of Set 8 | bandarbeyla
# Processing Record 12 of Set 8 | berezovyy
# Processing Record 13 of Set 8 | leshukonskoye
# Processing Record 14 of Set 8 | shizunai
# Processing Record 15 of Set 8 | yakeshi
# Processing Record 16 of Set 8 | saskylakh
# Processing Record 17 of Set 8 | babu
# Processing Record 18 of Set 8 | fredericksburg
# Processing Record 19 of Set 8 | yuzhno-kurilsk
# Processing Record 20 of Set 8 | zambezi
# Processing Record 21 of Set 8 | maarianhamina
# Processing Record 22 of Set 8 | westport
# Processing Record 23 of Set 8 | ulaanbaatar
# Processing Record 24 of Set 8 | mahebourg
# Processing Record 25 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 8 | koutiala
# Processing Record 27 of Set 8 | jaguey grande
# Processing Record 28 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 8 | rabak
# Processing Record 30 of Set 8 | tyukhtet
# Processing Record 31 of Set 8 | general roca
# Processing Record 32 of Set 8 | belle glade
# Processing Record 33 of Set 8 | grand gaube
# Processing Record 34 of Set 8 | tynda
# Processing Record 35 of Set 8 | dalby
# Processing Record 36 of Set 8 | chiavari
# Processing Record 37 of Set 8 | shimoda
# Processing Record 38 of Set 8 | thompson
# Processing Record 39 of Set 8 | grootfontein
# Processing Record 40 of Set 8 | les cayes
# Processing Record 41 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 8 | ithaki
# Processing Record 43 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 8 | de-kastri
# Processing Record 45 of Set 8 | segou
# Processing Record 46 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 8 | singaparna
# Processing Record 49 of Set 8 | necochea
# Processing Record 50 of Set 8 | taksimo
# Processing Record 1 of Set 9 | calabozo
# Processing Record 2 of Set 9 | dunedin
# Processing Record 3 of Set 9 | chapais
# Processing Record 4 of Set 9 | waipawa
# Processing Record 5 of Set 9 | grindavik
# Processing Record 6 of Set 9 | itaituba
# Processing Record 7 of Set 9 | port elizabeth
# Processing Record 8 of Set 9 | fare
# Processing Record 9 of Set 9 | deep river
# Processing Record 10 of Set 9 | manokwari
# Processing Record 11 of Set 9 | ouadda
# Processing Record 12 of Set 9 | havre-saint-pierre
# Processing Record 13 of Set 9 | bukit bakri
# City not found. Skipping...
# Processing Record 14 of Set 9 | galveston
# Processing Record 15 of Set 9 | emerald
# Processing Record 16 of Set 9 | kijang
# Processing Record 17 of Set 9 | artyom
# Processing Record 18 of Set 9 | itarema
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | arona
# Processing Record 21 of Set 9 | buri
# Processing Record 22 of Set 9 | port hedland
# Processing Record 23 of Set 9 | gushikawa
# Processing Record 24 of Set 9 | sulangan
# Processing Record 25 of Set 9 | faanui
# Processing Record 26 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 9 | rizhao
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | visby
# Processing Record 30 of Set 9 | stornoway
# Processing Record 31 of Set 9 | marzuq
# Processing Record 32 of Set 9 | udachnyy
# Processing Record 33 of Set 9 | havoysund
# Processing Record 34 of Set 9 | vesoul
# Processing Record 35 of Set 9 | kopayhorod
# Processing Record 36 of Set 9 | hayden
# Processing Record 37 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 9 | faya
# Processing Record 39 of Set 9 | todos santos
# Processing Record 40 of Set 9 | makung
# City not found. Skipping...
# Processing Record 41 of Set 9 | imeni poliny osipenko
# Processing Record 42 of Set 9 | agadez
# Processing Record 43 of Set 9 | simpang
# Processing Record 44 of Set 9 | tiznit
# Processing Record 45 of Set 9 | outjo
# Processing Record 46 of Set 9 | balakhta
# Processing Record 47 of Set 9 | neuquen
# Processing Record 48 of Set 9 | yuanping
# Processing Record 49 of Set 9 | cotoca
# Processing Record 50 of Set 9 | the valley
# Processing Record 1 of Set 10 | lukiv
# Processing Record 2 of Set 10 | truth or consequences
# Processing Record 3 of Set 10 | kafanchan
# Processing Record 4 of Set 10 | brentwood
# Processing Record 5 of Set 10 | lazaro cardenas
# Processing Record 6 of Set 10 | oranjemund
# Processing Record 7 of Set 10 | polkowice
# Processing Record 8 of Set 10 | samarai
# Processing Record 9 of Set 10 | balezino
# Processing Record 10 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 11 of Set 10 | kortkeros
# Processing Record 12 of Set 10 | sao joao da barra
# Processing Record 13 of Set 10 | mamakan
# Processing Record 14 of Set 10 | bukachacha
# Processing Record 15 of Set 10 | concarneau
# Processing Record 16 of Set 10 | ust-tsilma
# Processing Record 17 of Set 10 | honningsvag
# Processing Record 18 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 10 | ternate
# Processing Record 20 of Set 10 | tuatapere
# Processing Record 21 of Set 10 | yefira
# City not found. Skipping...
# Processing Record 22 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 10 | manado
# Processing Record 24 of Set 10 | dabakala
# Processing Record 25 of Set 10 | kasongo-lunda
# Processing Record 26 of Set 10 | arys
# Processing Record 27 of Set 10 | waingapu
# Processing Record 28 of Set 10 | marawi
# Processing Record 29 of Set 10 | lesogorsk
# Processing Record 30 of Set 10 | palhi
# Processing Record 31 of Set 10 | nyurba
# Processing Record 32 of Set 10 | taltal
# Processing Record 33 of Set 10 | porto novo
# Processing Record 34 of Set 10 | rocha
# Processing Record 35 of Set 10 | portel
# Processing Record 36 of Set 10 | puteyets
# Processing Record 37 of Set 10 | zyryanovsk
# Processing Record 38 of Set 10 | nantucket
# Processing Record 39 of Set 10 | alofi
# Processing Record 40 of Set 10 | komsomolskiy
# Processing Record 41 of Set 10 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 42 of Set 10 | tromso
# Processing Record 43 of Set 10 | iwanai
# Processing Record 44 of Set 10 | ghanzi
# Processing Record 45 of Set 10 | ugoofaaru
# Processing Record 46 of Set 10 | chincha alta
# Processing Record 47 of Set 10 | maksatikha
# Processing Record 48 of Set 10 | meulaboh
# Processing Record 49 of Set 10 | ryotsu
# Processing Record 50 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 11 | mahanoro
# Processing Record 2 of Set 11 | balkhash
# Processing Record 3 of Set 11 | mangla
# Processing Record 4 of Set 11 | caracoli
# Processing Record 5 of Set 11 | mangan
# Processing Record 6 of Set 11 | aykhal
# Processing Record 7 of Set 11 | sinnamary
# Processing Record 8 of Set 11 | oriximina
# Processing Record 9 of Set 11 | alvorada
# Processing Record 10 of Set 11 | auki
# Processing Record 11 of Set 11 | shaoguan
# Processing Record 12 of Set 11 | porto santo
# Processing Record 13 of Set 11 | ketchikan
# Processing Record 14 of Set 11 | bacolod
# Processing Record 15 of Set 11 | brae
# Processing Record 16 of Set 11 | solnechnyy
# Processing Record 17 of Set 11 | sobolevo
# Processing Record 18 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 11 | puqi
# Processing Record 20 of Set 11 | alihe
# Processing Record 21 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 11 | somes-odorhei
# Processing Record 23 of Set 11 | huarmey
# Processing Record 24 of Set 11 | high rock
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | bushehr
# Processing Record 27 of Set 11 | challans
# Processing Record 28 of Set 11 | matamoros
# Processing Record 29 of Set 11 | sibi
# Processing Record 30 of Set 11 | muzhi
# Processing Record 31 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 32 of Set 11 | banjar
# Processing Record 33 of Set 11 | bajos de haina
# Processing Record 34 of Set 11 | wakefield
# Processing Record 35 of Set 11 | tenango de rio blanco
# City not found. Skipping...
# Processing Record 36 of Set 11 | eenhana
# Processing Record 37 of Set 11 | dudinka
# Processing Record 38 of Set 11 | lola
# Processing Record 39 of Set 11 | tweed
# Processing Record 40 of Set 11 | susehri
# Processing Record 41 of Set 11 | la primavera
# Processing Record 42 of Set 11 | pathein
# Processing Record 43 of Set 11 | shingu
# Processing Record 44 of Set 11 | oum hadjer
# Processing Record 45 of Set 11 | dutlwe
# Processing Record 46 of Set 11 | benxi
# Processing Record 47 of Set 11 | basco
# Processing Record 48 of Set 11 | standish
# Processing Record 49 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 11 | esmeraldas
# Processing Record 1 of Set 12 | springbok
# Processing Record 2 of Set 12 | quang ngai
# Processing Record 3 of Set 12 | tecoanapa
# Processing Record 4 of Set 12 | kawalu
# Processing Record 5 of Set 12 | beberibe
# Processing Record 6 of Set 12 | mae sai
# Processing Record 7 of Set 12 | hastings
# Processing Record 8 of Set 12 | talcahuano
# Processing Record 9 of Set 12 | hami
# Processing Record 10 of Set 12 | hasaki
# Processing Record 11 of Set 12 | tadine
# Processing Record 12 of Set 12 | saint-pierre
# Processing Record 13 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 12 | storforshei
# Processing Record 15 of Set 12 | rovaniemi
# Processing Record 16 of Set 12 | erenhot
# Processing Record 17 of Set 12 | ambilobe
# Processing Record 18 of Set 12 | lokosovo
# Processing Record 19 of Set 12 | hit
# Processing Record 20 of Set 12 | san quintin
# Processing Record 21 of Set 12 | port macquarie
# Processing Record 22 of Set 12 | aitape
# Processing Record 23 of Set 12 | hai duong
# Processing Record 24 of Set 12 | bondo
# Processing Record 25 of Set 12 | humaita
# Processing Record 26 of Set 12 | santa vitoria do palmar
# Processing Record 27 of Set 12 | great yarmouth
# Processing Record 28 of Set 12 | rab
# City not found. Skipping...
# Processing Record 29 of Set 12 | planadas
# Processing Record 30 of Set 12 | berlevag
# Processing Record 31 of Set 12 | monrovia
# Processing Record 32 of Set 12 | shelbyville
# Processing Record 33 of Set 12 | aktas
# Processing Record 34 of Set 12 | andenes
# Processing Record 35 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 36 of Set 12 | obo
# Processing Record 37 of Set 12 | puerto morazan
# Processing Record 38 of Set 12 | tabuk
# Processing Record 39 of Set 12 | hovd
# Processing Record 40 of Set 12 | mankono
# Processing Record 41 of Set 12 | sar-e pul
# Processing Record 42 of Set 12 | marondera
# Processing Record 43 of Set 12 | uyar
# Processing Record 44 of Set 12 | korla
# Processing Record 45 of Set 12 | lorengau
# Processing Record 46 of Set 12 | zarechnyy
# Processing Record 47 of Set 12 | lusambo
# Processing Record 48 of Set 12 | gizo
# Processing Record 49 of Set 12 | longyearbyen
# Processing Record 50 of Set 12 | zhezkazgan
# Processing Record 1 of Set 13 | moldava nad bodvou
# Processing Record 2 of Set 13 | yar-sale
# Processing Record 3 of Set 13 | hangu
# Processing Record 4 of Set 13 | azangaro
# Processing Record 5 of Set 13 | maceio
# Processing Record 6 of Set 13 | lagoa santa
# Processing Record 7 of Set 13 | bremerhaven
# Processing Record 8 of Set 13 | kuytun
# Processing Record 9 of Set 13 | wichita falls
# Processing Record 10 of Set 13 | aklavik
# Processing Record 11 of Set 13 | caravelas
# Processing Record 12 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 13 | zdunska wola
# Processing Record 14 of Set 13 | tabora
# Processing Record 15 of Set 13 | dauphin
# Processing Record 16 of Set 13 | leninsk-kuznetskiy
# Processing Record 17 of Set 13 | campo grande
# Processing Record 18 of Set 13 | newton
# Processing Record 19 of Set 13 | grand forks
# Processing Record 20 of Set 13 | krutinka
# Processing Record 21 of Set 13 | uttarkashi
# Processing Record 22 of Set 13 | coron
# Processing Record 23 of Set 13 | sire
# Processing Record 24 of Set 13 | belaya gora
# Processing Record 25 of Set 13 | osorno
# Processing Record 26 of Set 13 | khanpur
# Processing Record 27 of Set 13 | tabou
# Processing Record 28 of Set 13 | clyde river
# Processing Record 29 of Set 13 | semibratovo
# Processing Record 30 of Set 13 | ruzhyn
# Processing Record 31 of Set 13 | tallahassee
# Processing Record 32 of Set 13 | le port
# Processing Record 33 of Set 13 | balkanabat
# Processing Record 34 of Set 13 | birao
# Processing Record 35 of Set 13 | pilar
# Processing Record 36 of Set 13 | minot
# Processing Record 37 of Set 13 | guatire
# Processing Record 38 of Set 13 | dingle
# Processing Record 39 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 13 | ridgecrest
# Processing Record 41 of Set 13 | kifri
# Processing Record 42 of Set 13 | aasiaat
# Processing Record 43 of Set 13 | kavaratti
# Processing Record 44 of Set 13 | newark
# Processing Record 45 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 13 | terrace
# Processing Record 47 of Set 13 | whitehorse
# Processing Record 48 of Set 13 | ilo
# Processing Record 49 of Set 13 | bealanana
# Processing Record 50 of Set 13 | kholm-zhirkovskiy
# Processing Record 1 of Set 14 | tarusa
# Processing Record 2 of Set 14 | nouadhibou
# Processing Record 3 of Set 14 | mosquera
# Processing Record 4 of Set 14 | lodja
# Processing Record 5 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 14 | wum
# Processing Record 7 of Set 14 | buraydah
# Processing Record 8 of Set 14 | vila franca do campo
# Processing Record 9 of Set 14 | ancud
# Processing Record 10 of Set 14 | nur
# Processing Record 11 of Set 14 | diapaga
# Processing Record 12 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 14 | la ronge
# Processing Record 14 of Set 14 | ossora
# Processing Record 15 of Set 14 | hualmay
# Processing Record 16 of Set 14 | alyangula
# Processing Record 17 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 14 | ji-parana
# City not found. Skipping...
# Processing Record 19 of Set 14 | princeton
# Processing Record 20 of Set 14 | kinablangan
# Processing Record 21 of Set 14 | burley
# Processing Record 22 of Set 14 | port blair
# Processing Record 23 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 14 | mercedes
# Processing Record 25 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 26 of Set 14 | jumla
# Processing Record 27 of Set 14 | phalaborwa
# Processing Record 28 of Set 14 | honiara
# Processing Record 29 of Set 14 | tshikapa
# Processing Record 30 of Set 14 | salta
# Processing Record 31 of Set 14 | los andes
# Processing Record 32 of Set 14 | arman
# Processing Record 33 of Set 14 | amapa
# Processing Record 34 of Set 14 | lamu
# Processing Record 35 of Set 14 | kenora
# Processing Record 36 of Set 14 | nelson bay
# Processing Record 37 of Set 14 | puerto escondido
# Processing Record 38 of Set 14 | mizque
# Processing Record 39 of Set 14 | camacha
# Processing Record 40 of Set 14 | kaduqli
# Processing Record 41 of Set 14 | codrington
# Processing Record 42 of Set 14 | aquiraz
# Processing Record 43 of Set 14 | gore
# Processing Record 44 of Set 14 | dallas
# Processing Record 45 of Set 14 | nizhniy baskunchak
# Processing Record 46 of Set 14 | balikpapan
# Processing Record 47 of Set 14 | taguisa
# Processing Record 48 of Set 14 | bathurst
# Processing Record 49 of Set 14 | touros
# Processing Record 50 of Set 14 | mandalgovi
# Processing Record 1 of Set 15 | la trinidad
# Processing Record 2 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 15 | puerto narino
# Processing Record 4 of Set 15 | palmer
# Processing Record 5 of Set 15 | ouesso
# Processing Record 6 of Set 15 | gornopravdinsk
# Processing Record 7 of Set 15 | san francisco de macoris
# Processing Record 8 of Set 15 | preobrazheniye
# Processing Record 9 of Set 15 | djambala
# Processing Record 10 of Set 15 | parana
# Processing Record 11 of Set 15 | adrar
# Processing Record 12 of Set 15 | nador
# Processing Record 13 of Set 15 | coahuayana
# Processing Record 14 of Set 15 | glenwood springs
# Processing Record 15 of Set 15 | teya
# Processing Record 16 of Set 15 | port lincoln
# Processing Record 17 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 19 of Set 15 | kandrian
# Processing Record 20 of Set 15 | burica
# City not found. Skipping...
# Processing Record 21 of Set 15 | gornozavodsk
# Processing Record 22 of Set 15 | alta floresta
# Processing Record 23 of Set 15 | ankara
# Processing Record 24 of Set 15 | juneau
# Processing Record 25 of Set 15 | excelsior springs
# Processing Record 26 of Set 15 | kosh-agach
# Processing Record 27 of Set 15 | wenling
# Processing Record 28 of Set 15 | conceicao da barra
# Processing Record 29 of Set 15 | kilindoni
# Processing Record 30 of Set 15 | cururupu
# Processing Record 31 of Set 15 | hongjiang
# Processing Record 32 of Set 15 | portland
# Processing Record 33 of Set 15 | januaria
# Processing Record 34 of Set 15 | cowra
# Processing Record 35 of Set 15 | bonthe
# Processing Record 36 of Set 15 | kaman
# Processing Record 37 of Set 15 | bambanglipuro
# Processing Record 38 of Set 15 | nabire
# Processing Record 39 of Set 15 | barcelos
# Processing Record 40 of Set 15 | liverpool
# Processing Record 41 of Set 15 | durres
# Processing Record 42 of Set 15 | fort-shevchenko
# Processing Record 43 of Set 15 | talaja
# Processing Record 44 of Set 15 | tazovskiy
# Processing Record 45 of Set 15 | belem
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 675

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kapaa  22.08 -159.32     82.40        65           1        4.70
# 1   Hervey Bay -25.30  152.85     72.00        93          81        4.00
# 2    Cape Town -33.93   18.42     64.00        67           0        3.36
# 3      Bubaque  11.28  -15.83     80.83        62           0       10.40
# 4  Port Alfred -33.59   26.89     66.00        96          25       18.01
#
#   Country Current Description
# 0      US           clear sky
# 1      AU       broken clouds
# 2      ZA           clear sky
# 3      GW           clear sky
# 4      ZA    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa      US  22.08 -159.32     82.40        65           1
# 1    Hervey Bay      AU -25.30  152.85     72.00        93          81
# 2     Cape Town      ZA -33.93   18.42     64.00        67           0
# 3       Bubaque      GW  11.28  -15.83     80.83        62           0
# 4   Port Alfred      ZA -33.59   26.89     66.00        96          25
# 5      Barkhera      IN  28.45   79.80     52.47        68           0
# 6  Punta Arenas      CL -53.15  -70.92     51.80        57          40
# 7        Inuvik      CA  68.35 -133.72    -32.80        66          30
# 8      Olafsvik      IS  64.89  -23.71     38.50        78          99
# 9   Sakaiminato      JP  35.55  133.23     44.60        90          75
#
#    Wind Speed          Current Description
# 0        4.70                    clear sky
# 1        4.00                broken clouds
# 2        3.36                    clear sky
# 3       10.40                    clear sky
# 4       18.01             scattered clouds
# 5        7.56                    clear sky
# 6       24.16             scattered clouds
# 7        4.70             scattered clouds
# 8       23.85                   light rain
# 9       13.87  light intensity shower rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
